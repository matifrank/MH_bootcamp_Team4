# %% [markdown]
# # Taller de Pandas - COVID

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 🧼 Importar Pandas

# %%
import pandas as pd

# %% [markdown]
# 🧼 Leer el .csv "Covid19Argentina"

# %%
covid = pd.read_csv('Covid19Argentina.csv')
covid
# Out:
#       Testing_Date      Province  Province_Code             District  \
# 0       2008-08-13         Jujuy             38  Dr. Manuel Belgrano
# 1       2019-07-13          CABA              2            COMUNA 02
# 2       2020-02-11          CABA              2            COMUNA 04
# 3       2020-02-20  Buenos Aires              6         Bahía Blanca
# 4       2020-02-20          CABA              2            COMUNA 04
# ...            ...           ...            ...                  ...
# 17519   2020-08-27         Jujuy             38             Palpalá
# 17520   2020-08-27          CABA              2            COMUNA 04
# 17521   2020-08-27  Buenos Aires              6     Florencio Varela
# 17522   2020-08-27          CABA              2            COMUNA 09
# 17523   2020-08-29          CABA              2            COMUNA 04
#
#        District_Code               Locality  Locality_Code Financing  \
# ...

# %% [markdown]
# 🧼 Imprimir los primeros 5 registros del dataframe

# %%
covid.head()
# Out:
#   Testing_Date      Province  Province_Code             District  \
# 0   2008-08-13         Jujuy             38  Dr. Manuel Belgrano
# 1   2019-07-13          CABA              2            COMUNA 02
# 2   2020-02-11          CABA              2            COMUNA 04
# 3   2020-02-20  Buenos Aires              6         Bahía Blanca
# 4   2020-02-20          CABA              2            COMUNA 04
#
#    District_Code               Locality  Locality_Code Financing  \
# 0             21  SAN SALVADOR DE JUJUY             60    Public
# 1              2               RECOLETA             10    Public
# 2              4       PARQUE PATRICIOS             10    Public
# 3             56           BAHIA BLANCA             10   Private
# 4              4       PARQUE PATRICIOS             10    Public
#
#                 Type  Total_Tests  Positive_Cases
# 0         Provincial            1             0.0
# 1  Public University            1             0.0
# ...

# %% [markdown]
# 🧼 Imprimir la cantidad de filas y columnas del df

# %%
covid.shape
# Out:
# (17524, 11)

# %% [markdown]
# 🧼 Utiliza un metodo perteneciente a los df para imprimir las columnas, la cantidad de no-nulos de cada una y el tipo de dato

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17524 entries, 0 to 17523
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Testing_Date    17524 non-null  object
#  1   Province        17522 non-null  object
#  2   Province_Code   17524 non-null  int64
#  3   District        17524 non-null  object
#  4   District_Code   17524 non-null  int64
#  5   Locality        17524 non-null  object
#  6   Locality_Code   17524 non-null  int64
#  7   Financing       17524 non-null  object
#  8   Type            17524 non-null  object
#  9   Total_Tests     17524 non-null  int64
#  10  Positive_Cases  17522 non-null  float64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# 🧼 Utiliza un metodo perteneciente a los df para imprimir informacion estadistica del df

# %%
covid.describe()
# Out:
#        Province_Code  District_Code  Locality_Code   Total_Tests  \
# count   17524.000000   17524.000000   17524.000000  17524.000000
# mean       24.615328     158.231340      53.242981     71.154873
# std        28.522829     230.802172      95.104505    148.029044
# min         2.000000       0.000000       0.000000      1.000000
# 25%         2.000000      12.000000      10.000000      4.000000
# 50%         6.000000      35.000000      10.000000     21.000000
# 75%        50.000000     260.000000      50.000000     68.000000
# max        99.000000     882.000000     560.000000   1738.000000
#
#        Positive_Cases
# count    17522.000000
# mean        23.326618
# std         64.207189
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%         18.000000
# max        943.000000

# %% [markdown]
# ⚠️¿Hay nulos en el df?⚠️
#
# El tratamiento de los nulos es "todo un tema", pero generalmente podemos decir que hay 4 posibles vias de accion:
#
# 🦠Eliminar los registros que tienen nulos
#
# 🦠Eliminar las columnas que tengan nulos (aconsejable si hay una columna con muchisimos nulos)
#
# 🦠Rellenar los nulos con medidas estadisticas: promedio, mediana y moda
#
# 🦠Rellenar los nulos con un algoritmo de aprendizaje automatico

# %% [markdown]
# 🧼 Imprimir solo las filas que contengan nulo en alguna columna

# %%
covid.isnull()
covid
# Out:
#       Testing_Date      Province  Province_Code             District  \
# 0       2008-08-13         Jujuy             38  Dr. Manuel Belgrano
# 1       2019-07-13          CABA              2            COMUNA 02
# 2       2020-02-11          CABA              2            COMUNA 04
# 3       2020-02-20  Buenos Aires              6         Bahía Blanca
# 4       2020-02-20          CABA              2            COMUNA 04
# ...            ...           ...            ...                  ...
# 17519   2020-08-27         Jujuy             38             Palpalá
# 17520   2020-08-27          CABA              2            COMUNA 04
# 17521   2020-08-27  Buenos Aires              6     Florencio Varela
# 17522   2020-08-27          CABA              2            COMUNA 09
# 17523   2020-08-29          CABA              2            COMUNA 04
#
#        District_Code               Locality  Locality_Code Financing  \
# ...

# %% [markdown]
# 🧼 Eliminar los registros que tienen nulos

# %%
covid.dropna(axis=0, inplace= True, how='all')
covid.shape
# Out:
# (17524, 11)

# %% [markdown]
# ⚠️A partir de ahora trabajaremos con el df sin nulos⚠️

# %% [markdown]
# 🧼 Ordenar el df en orden descendente tomando como referencia Testing_Date

# %%
covid.sort_values(by='Testing_Date', ascending=False)
# Out:
#       Testing_Date      Province  Province_Code             District  \
# 17523   2020-08-29          CABA              2            COMUNA 04
# 17402   2020-08-27          CABA              2            COMUNA 02
# 17420   2020-08-27       Neuquén             58          Confluencia
# 17419   2020-08-27  Buenos Aires              6   General San Martín
# 17418   2020-08-27  Buenos Aires              6           San Miguel
# ...            ...           ...            ...                  ...
# 4       2020-02-20          CABA              2            COMUNA 04
# 3       2020-02-20  Buenos Aires              6         Bahía Blanca
# 2       2020-02-11          CABA              2            COMUNA 04
# 1       2019-07-13          CABA              2            COMUNA 02
# 0       2008-08-13         Jujuy             38  Dr. Manuel Belgrano
#
#        District_Code               Locality  Locality_Code Financing  \
# ...

# %% [markdown]
# 🧼 Ordenar el df en orden ascendente tomando como referencia Testing_Date

# %%
covid.sort_values(by='Testing_Date', ascending=True)
# Out:
#       Testing_Date      Province  Province_Code             District  \
# 0       2008-08-13         Jujuy             38  Dr. Manuel Belgrano
# 1       2019-07-13          CABA              2            COMUNA 02
# 2       2020-02-11          CABA              2            COMUNA 04
# 3       2020-02-20  Buenos Aires              6         Bahía Blanca
# 4       2020-02-20          CABA              2            COMUNA 04
# ...            ...           ...            ...                  ...
# 17417   2020-08-27     Río Negro             62         General Roca
# 17418   2020-08-27  Buenos Aires              6           San Miguel
# 17419   2020-08-27  Buenos Aires              6   General San Martín
# 17401   2020-08-27  Buenos Aires              6  Malvinas Argentinas
# 17523   2020-08-29          CABA              2            COMUNA 04
#
#        District_Code               Locality  Locality_Code Financing  \
# ...

# %% [markdown]
# ⚠️¿Podes ver alguna incongruencia en los datos?⚠️

# %% [markdown]
# 🧼Eliminar los registros cuyo Testing_Date sea anterior al primer registro de covid en China: 17 de Noviembre de 2019

# %%
covid_argentina = covid[covid['Testing_Date'] >= '2019-11-17']
covid_argentina.sort_values(by='Testing_Date', ascending=True)
# Out:
#       Testing_Date             Province  Province_Code             District  \
# 2       2020-02-11                 CABA              2            COMUNA 04
# 3       2020-02-20         Buenos Aires              6         Bahía Blanca
# 4       2020-02-20                 CABA              2            COMUNA 04
# 5       2020-02-25  Santiago del Estero             86         Capital City
# 6       2020-02-27  Santiago del Estero             86         Capital City
# ...            ...                  ...            ...                  ...
# 17417   2020-08-27            Río Negro             62         General Roca
# 17418   2020-08-27         Buenos Aires              6           San Miguel
# 17419   2020-08-27         Buenos Aires              6   General San Martín
# 17401   2020-08-27         Buenos Aires              6  Malvinas Argentinas
# 17523   2020-08-29                 CABA              2            COMUNA 04
#
# ...

# %% [markdown]
# 🧼Resetear el indice del df:

# %%
covid_argentina.reset_index(drop=True, inplace=True)

# %% [markdown]
# 🧼Analizar la distribucion de registros en las diferentes provincias

# %%
covid_registro_por_provincia = covid_argentina.groupby('Province')
covid_recuento_por_provincia = covid_registro_por_provincia.size()
covid_recuento_por_provincia
# Out:
# Province
# Buenos Aires           5664
# CABA                   4529
# Catamarca               123
# Chaco                   406
# Chubut                  487
# Corrientes              172
# Córdoba                 424
# Entre Ríos              245
# Formosa                 142
# Jujuy                   305
# La Pampa                214
# La Rioja                253
# Mendoza                 818
# Misiones                148
# NOT SPECIFIED            27
# Neuquén                 319
# Río Negro               991
# Salta                   292
# San Juan                165
# San Luis                135
# Santa Cruz              339
# Santa Fe                726
# Santiago del Estero     158
# Tierra del Fuego        179
# Tucumán                 259
# dtype: int64

# %%
import matplotlib.pyplot as plt
covid_recuento_por_provincia.plot(kind='bar', figsize=(12, 6))
plt.xlabel('Provincia')
plt.ylabel('Recuento de registros')
plt.title('Distribución de registros por provincia')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 🧼Calcular la cantidad de valores unicos en la columna Province

# %%
unique_provinces = covid_argentina['Province'].unique()
unique_provinces
# Out:
# array(['CABA', 'Buenos Aires', 'Santiago del Estero', nan, 'Córdoba',
#        'Santa Fe', 'Neuquén', 'Chaco', 'Tierra del Fuego', 'San Luis',
#        'Corrientes', 'Río Negro', 'Mendoza', 'Formosa', 'Misiones',
#        'Entre Ríos', 'Catamarca', 'Jujuy', 'Tucumán', 'Salta', 'La Pampa',
#        'La Rioja', 'Chubut', 'Santa Cruz', 'San Juan', 'NOT SPECIFIED'],
#       dtype=object)

# %%
unique_count = len(unique_provinces)
print("Cantidad de valores únicos en Province:", unique_count)
# Out:
# Cantidad de valores únicos en Province: 26

# %% [markdown]
# ⚠️Vemos que la cantidad de valores unicos coincide con las 24 jurisdicciones: 23 provincias y Capital Federal + Una categoria "NOT SPECIFIED"

# %% [markdown]
# 🦠Analizar la distribucion de registros por Financing y Type

# %%
registros_financing_type = covid_argentina.groupby(['Financing', 'Type'])
recuento_financing_type = registros_financing_type.size()
print(recuento_financing_type)
# Out:
# Financing  Type
# Private    Mixed                  154
#            Mutual                   3
#            Private               5825
#            Private University       3
#            Social Security        244
# Public     Armed forces           426
#            Municipal             2622
#            National              1070
#            Prison Service           7
#            Provincial            6730
#            Public University      438
# dtype: int64

# %%
recuento_financing_type.unstack('Financing').plot(kind='bar', stacked=True, figsize=(10, 6))
plt.xlabel('Type')
plt.ylabel('Recuento de registros')
plt.title('Distribución de registros por Financing y Type')
plt.legend(title='Financing')
plt.show()

# %% [markdown]
# 🦠Agregar una nueva columna llamada "Alerta" la cual tendra 1 si la cantidad de casos positivos supera la mediana, en caso contrario un 0

# %%
mediana_casos_positivos = covid_argentina["Positive_Cases"].median()
mediana_casos_positivos
# Out:
# 2.0

# %%
def Alerta(casos_positivos):
    if casos_positivos > mediana_casos_positivos:
        return 1
    else:
        return 0

# %%
covid_argentina["Alerta"] = covid_argentina["Positive_Cases"].apply(Alerta)
# Out:
# <ipython-input-150-c6192f4278a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_argentina["Alerta"] = covid_argentina["Positive_Cases"].apply(Alerta)

# %%
covid_argentina.loc[
    covid_argentina['Positive_Cases'] >
    mediana_casos_positivos, 'Alerta'] = 1
print(covid_argentina)
# Out:
#       Testing_Date             Province  Province_Code          District  \
# 0       2020-02-11                 CABA              2         COMUNA 04
# 1       2020-02-20         Buenos Aires              6      Bahía Blanca
# 2       2020-02-20                 CABA              2         COMUNA 04
# 3       2020-02-25  Santiago del Estero             86      Capital City
# 4       2020-02-27  Santiago del Estero             86      Capital City
# ...            ...                  ...            ...               ...
# 17517   2020-08-27                Jujuy             38          Palpalá
# 17518   2020-08-27                 CABA              2         COMUNA 04
# 17519   2020-08-27         Buenos Aires              6  Florencio Varela
# 17520   2020-08-27                 CABA              2         COMUNA 09
# 17521   2020-08-29                 CABA              2         COMUNA 04
#
#        District_Code             Locality  Locality_Code Financing  \
# ...

# %% [markdown]
# 🦠 Hay una forma mucho mas facil:

# %% [markdown]
# 😵 **Ejercicios** 😵

# %% [markdown]
# ✔️1.Crear una nueva columna llamada Positividad la cual sea igual a la division
# de los casos positivos entre el total de tests

# %%
covid_argentina["Positividad"] = covid_argentina["Positive_Cases"] / covid_argentina["Total_Tests"]
# Out:
# <ipython-input-152-aa8a11206e8e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   covid_argentina["Positividad"] = covid_argentina["Positive_Cases"] / covid_argentina["Total_Tests"]

# %%
covid_argentina.loc[:, "Positividad"] = covid_argentina["Positive_Cases"] / covid_argentina["Total_Tests"]
covid_argentina
# Out:
#       Testing_Date             Province  Province_Code          District  \
# 0       2020-02-11                 CABA              2         COMUNA 04
# 1       2020-02-20         Buenos Aires              6      Bahía Blanca
# 2       2020-02-20                 CABA              2         COMUNA 04
# 3       2020-02-25  Santiago del Estero             86      Capital City
# 4       2020-02-27  Santiago del Estero             86      Capital City
# ...            ...                  ...            ...               ...
# 17517   2020-08-27                Jujuy             38          Palpalá
# 17518   2020-08-27                 CABA              2         COMUNA 04
# 17519   2020-08-27         Buenos Aires              6  Florencio Varela
# 17520   2020-08-27                 CABA              2         COMUNA 09
# 17521   2020-08-29                 CABA              2         COMUNA 04
#
#        District_Code             Locality  Locality_Code Financing  \
# ...

# %% [markdown]
# ✔️2.Obtener un dataframe con solo registros de CABA y tengan localidad en parque patricios

# %%
caba_parque_patricios = covid_argentina.loc[
    (covid_argentina['Province'] == 'CABA') &
    (covid_argentina['Locality'] == 'PARQUE PATRICIOS')
]
caba_parque_patricios
# Out:
#       Testing_Date Province  Province_Code   District  District_Code  \
# 0       2020-02-11     CABA              2  COMUNA 04              4
# 2       2020-02-20     CABA              2  COMUNA 04              4
# 5       2020-02-27     CABA              2  COMUNA 04              4
# 6       2020-02-28     CABA              2  COMUNA 04              4
# 8       2020-03-03     CABA              2  COMUNA 04              4
# ...            ...      ...            ...        ...            ...
# 17337   2020-08-26     CABA              2  COMUNA 04              4
# 17460   2020-08-27     CABA              2  COMUNA 04              4
# 17482   2020-08-27     CABA              2  COMUNA 04              4
# 17518   2020-08-27     CABA              2  COMUNA 04              4
# 17521   2020-08-29     CABA              2  COMUNA 04              4
#
#                Locality  Locality_Code Financing       Type  Total_Tests  \
# ...

# %% [markdown]
# ✔️3.Obtener un dataframe con solo registros de Buenos Aires que sean de tipo privado y tengan casos positivos superiores a 10, finalmente ordena de forma descendente

# %%
bsas_privado = covid_argentina.loc[
    (covid_argentina['Province'] == 'Buenos Aires') &
    (covid_argentina['Type'] == 'Private') &
    (covid_argentina['Positive_Cases'] > 10)
]
bsas_privado_ordenado = bsas_privado.sort_values(by='Positive_Cases', ascending=False)
bsas_privado_ordenado
# Out:
#       Testing_Date      Province  Province_Code      District  District_Code  \
# 11322   2020-07-24  Buenos Aires              6  Bahía Blanca             56
# 17082   2020-08-25  Buenos Aires              6      La Plata            441
# 13930   2020-08-08  Buenos Aires              6  Bahía Blanca             56
# 14926   2020-08-14  Buenos Aires              6  Bahía Blanca             56
# 15880   2020-08-19  Buenos Aires              6      La Plata            441
# ...            ...           ...            ...           ...            ...
# 9260    2020-07-09  Buenos Aires              6       Quilmes            658
# 12171   2020-07-29  Buenos Aires              6    San Isidro            756
# 9356    2020-07-10  Buenos Aires              6    La Matanza            427
# 14308   2020-08-10  Buenos Aires              6    San Miguel            760
# 14114   2020-08-09  Buenos Aires              6    Hurlingham            408
#
# ...

# %% [markdown]
# ✔️4.Obtener un dataframe con registros que pertenezcan a Buenos Aires o tengan mas de 10 test realizados

# %%
filtro = covid_argentina.loc[
    (covid_argentina['Province'] == 'Buenos Aires') |
    (covid_argentina['Total_Tests'] > 10)
]
filtro
# Out:
#       Testing_Date      Province  Province_Code          District  \
# 1       2020-02-20  Buenos Aires              6      Bahía Blanca
# 11      2020-03-06          CABA              2         COMUNA 04
# 14      2020-03-08          CABA              2         COMUNA 04
# 15      2020-03-09          CABA              2         COMUNA 04
# 17      2020-03-10          CABA              2         COMUNA 04
# ...            ...           ...            ...               ...
# 17513   2020-08-27       Mendoza             50        Guaymallén
# 17514   2020-08-27         Jujuy             38         El Carmen
# 17515   2020-08-27  Buenos Aires              6   Lomas de Zamora
# 17516   2020-08-27      Misiones             54      Capital City
# 17519   2020-08-27  Buenos Aires              6  Florencio Varela
#
#        District_Code                        Locality  Locality_Code Financing  \
# 1                 56                    BAHIA BLANCA             10   Private
# ...

# %% [markdown]
# ✔️5.Obtener un dataframe que contenga solo los registros cuya provincia contenga el string "San"

# %%
filtro_san = covid_argentina.loc[
    covid_argentina['Province'].str.contains('San', case=False, na=False)
]

filtro_san
# Out:
#       Testing_Date             Province  Province_Code      District  \
# 3       2020-02-25  Santiago del Estero             86  Capital City
# 4       2020-02-27  Santiago del Estero             86  Capital City
# 13      2020-03-08  Santiago del Estero             86  Capital City
# 19      2020-03-11             Santa Fe             82       Rosario
# 35      2020-03-18             Santa Fe             82       Rosario
# ...            ...                  ...            ...           ...
# 17444   2020-08-27             Santa Fe             82       Caseros
# 17445   2020-08-27             Santa Fe             82       Rosario
# 17451   2020-08-27             Santa Fe             82       Caseros
# 17484   2020-08-27  Santiago del Estero             86  Capital City
# 17507   2020-08-27             San Luis             74    La Capital
#
#        District_Code             Locality  Locality_Code Financing  \
# 3                 49  SANTIAGO DEL ESTERO            110    Public
# ...

# %% [markdown]
# ✔️6.Obtener un dataframe que contenga solo registros cuyos casos positivos se encuentren entre 10 y 20

# %%
filtro_10_20 = covid_argentina.loc[
    (covid_argentina['Positive_Cases'] >= 10) &
    (covid_argentina['Positive_Cases'] <= 20)
]

filtro_10_20
# Out:
#       Testing_Date      Province  Province_Code          District  \
# 21      2020-03-12          CABA              2         COMUNA 04
# 26      2020-03-15          CABA              2         COMUNA 04
# 29      2020-03-16          CABA              2         COMUNA 04
# 30      2020-03-17          CABA              2         COMUNA 04
# 71      2020-03-22      Santa Fe             82           Rosario
# ...            ...           ...            ...               ...
# 17490   2020-08-27       Neuquén             58       Confluencia
# 17500   2020-08-27  Buenos Aires              6            Ezeiza
# 17514   2020-08-27         Jujuy             38         El Carmen
# 17515   2020-08-27  Buenos Aires              6   Lomas de Zamora
# 17519   2020-08-27  Buenos Aires              6  Florencio Varela
#
#        District_Code                         Locality  Locality_Code  \
# 21                 4                 PARQUE PATRICIOS             10
# ...

# %% [markdown]
# ✔️7.Obtener SOLO el registro que contenga la mayor cantidad de casos positivos, posteriormente hacer un print de estos casos (sin copiar el dato a mano)

# %%
registro_maximo = covid_argentina.loc[
    covid_argentina['Positive_Cases'] ==
    covid_argentina['Positive_Cases'].max()
]
print("Máxima cantidad de casos positivos:", registro_maximo['Positive_Cases'].values[0])
# Out:
# Máxima cantidad de casos positivos: 943.0

# %% [markdown]
# ✔️8.Cual es el porcentaje de registros que pertenecen a CABA?

# %%
conteo_CABA = covid_argentina[covid_argentina['Province'] == 'CABA'].shape[0]
total_CABA = covid_argentina.shape[0]
porcentaje_CABA = (conteo_CABA / total_CABA) * 100

print(" porcentaje de registros que pertenecen a CABA:", round(porcentaje_CABA, 2), "%")
# Out:
#  porcentaje de registros que pertenecen a CABA: 25.85 %

# %% [markdown]
# # GROUP BY

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 🦠Vemos como agrupó

# %% [markdown]
# 🦠Agrupar el df de covid por Provincia, realizando una agregacion de suma en la columna de casos positivos, ordenar de forma descendente por numero de casos

# %%
grouped_data = covid_argentina.groupby('Province')['Positive_Cases'].sum().reset_index()
sorted_grouped_data = grouped_data.sort_values(by='Positive_Cases', ascending=False)

sorted_grouped_data
# Out:
#                Province  Positive_Cases
# 1                  CABA        235696.0
# 0          Buenos Aires        115422.0
# 6               Córdoba          8080.0
# 21             Santa Fe          7221.0
# 9                 Jujuy          6076.0
# 12              Mendoza          5820.0
# 3                 Chaco          5654.0
# 16            Río Negro          5566.0
# 17                Salta          4055.0
# 15              Neuquén          3309.0
# 7            Entre Ríos          2797.0
# 24              Tucumán          1915.0
# 23     Tierra del Fuego          1669.0
# 20           Santa Cruz          1640.0
# 11             La Rioja          1399.0
# 22  Santiago del Estero           723.0
# 4                Chubut           690.0
# 18             San Juan           218.0
# 5            Corrientes           215.0
# 10             La Pampa           196.0
# 8               Formosa           145.0
# 2             Catamarca            80.0
# ...

# %% [markdown]
# 🧼 Que paso?

# %% [markdown]
# 🧼 Agrupar el df de covid por Provincia y por tipo de financiamiento, realizando una agregacion de suma en la columna de casos positivos, ordenar de forma descendente por numero de casos

# %%
data_agrupada = (
    covid_argentina.groupby(['Province', 'Financing'])['Positive_Cases']
    .sum()
    .reset_index()
)

data_agrupada_ordenada = data_agrupada.sort_values(by='Positive_Cases', ascending=False)
data_agrupada_ordenada
# Out:
#                Province Financing  Positive_Cases
# 3                  CABA    Public        121738.0
# 2                  CABA   Private        113958.0
# 1          Buenos Aires    Public         89521.0
# 0          Buenos Aires   Private         25901.0
# 13              Córdoba    Public          7616.0
# 18                Jujuy    Public          5723.0
# 24              Mendoza    Public          5490.0
# 7                 Chaco    Public          5397.0
# 31            Río Negro    Public          5220.0
# 41             Santa Fe    Public          4153.0
# 40             Santa Fe   Private          3068.0
# 29              Neuquén    Public          2739.0
# 15           Entre Ríos    Public          2720.0
# 32                Salta   Private          2227.0
# 33                Salta    Public          1828.0
# 47              Tucumán    Public          1678.0
# 45     Tierra del Fuego    Public          1659.0
# 22             La Rioja    Public          1392.0
# ...
